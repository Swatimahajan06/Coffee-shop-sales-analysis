# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td><td>0</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %fs ls dbfs:/FileStore/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/</td><td>tables/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# Import necessary libraries
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("coffee_Shop_sales_analysis") \
    .getOrCreate()


df = spark.read.csv("dbfs:/FileStore/tables/", header=True, inferSchema=True)

df.show(5)
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|  product_category|        product_type|      product_detail|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+
# |             1|      2023-01-01|2024-08-14 07:06:11|              2|       5|Lower Manhattan|        32|       3.0|            Coffee|Gourmet brewed co...|         Ethiopia Rg|
# |             2|      2023-01-01|2024-08-14 07:08:56|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|
# |             3|      2023-01-01|2024-08-14 07:14:04|              2|       5|Lower Manhattan|        59|       4.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Lg|
# |             4|      2023-01-01|2024-08-14 07:20:24|              1|       5|Lower Manhattan|        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|
# |             5|      2023-01-01|2024-08-14 07:22:41|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
df.take(5)
# Out:
# Out[2]: [Row(transaction_id=1, transaction_date=datetime.date(2023, 1, 1), transaction_time=datetime.datetime(2024, 8, 14, 7, 6, 11), transaction_qty=2, store_id=5, store_location='Lower Manhattan', product_id=32, unit_price=3.0, product_category='Coffee', product_type='Gourmet brewed coffee', product_detail='Ethiopia Rg'),
#  Row(transaction_id=2, transaction_date=datetime.date(2023, 1, 1), transaction_time=datetime.datetime(2024, 8, 14, 7, 8, 56), transaction_qty=2, store_id=5, store_location='Lower Manhattan', product_id=57, unit_price=3.1, product_category='Tea', product_type='Brewed Chai tea', product_detail='Spicy Eye Opener Chai Lg'),
#  Row(transaction_id=3, transaction_date=datetime.date(2023, 1, 1), transaction_time=datetime.datetime(2024, 8, 14, 7, 14, 4), transaction_qty=2, store_id=5, store_location='Lower Manhattan', product_id=59, unit_price=4.5, product_category='Drinking Chocolate', product_type='Hot chocolate', product_detail='Dark chocolate Lg'),
#  Row(transaction_id=4, transaction_date=datetime.date(2023, 1, 1), transaction_time=datetime.datetime(2024, 8, 14, 7, 20, 24), transaction_qty=1, store_id=5, store_location='Lower Manhattan', product_id=22, unit_price=2.0, product_category='Coffee', product_type='Drip coffee', product_detail='Our Old Time Diner Blend Sm'),
#  Row(transaction_id=5, transaction_date=datetime.date(2023, 1, 1), transaction_time=datetime.datetime(2024, 8, 14, 7, 22, 41), transaction_qty=2, store_id=5, store_location='Lower Manhattan', product_id=57, unit_price=3.1, product_category='Tea', product_type='Brewed Chai tea', product_detail='Spicy Eye Opener Chai Lg')]

# %%
# Number of rows
num_rows = df.count()

# Number of columns
num_columns = len(df.columns)

# Print the shape of the DataFrame
print(f"Shape: ({num_rows}, {num_columns})")
# Out:
# Shape: (447402, 11)

# %%
# Print the schema of the DataFrame (data types of each column)
df.printSchema()

# Show summary statistics (e.g., count, mean, stddev, min, max) for numeric columns
df.describe().show()
# Out:
# root
#  |-- transaction_id: integer (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_time: timestamp (nullable = true)
#  |-- transaction_qty: integer (nullable = true)
#  |-- store_id: integer (nullable = true)
#  |-- store_location: string (nullable = true)
#  |-- product_id: integer (nullable = true)
#  |-- unit_price: double (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- product_type: string (nullable = true)
#  |-- product_detail: string (nullable = true)
#
# +-------+-----------------+------------------+-----------------+---------------+------------------+------------------+----------------+----------------+--------------------+
# |summary|   transaction_id|   transaction_qty|         store_id| store_location|        product_id|        unit_price|product_category|    product_type|      product_detail|
# +-------+-----------------+------------------+-----------------+---------------+------------------+------------------+----------------+----------------+--------------------+
# |  count|           447402|            447402|           447402|         447396|            447402|            447399|          447399|          447399|              447399|
# |   mean|74728.35245483927|1.4382836911770622|5.342041385599528|           null| 47.91887832419167| 3.382181542649976|            null|            null|                null|
# | stddev|43158.70741237079|0.5425030462067035|2.074125408677048|           null|17.930060710265444|2.6585779841355572|            null|            null|                null|
# |    min|                1|                 1|                3|        Astoria|                 1|               0.8|          Bakery|Barista Espresso|    Almond Croissant|
# |    max|           149456|                 8|                8|Lower Manhattan|                87|              45.0|             Tea|Sugar free syrup|Traditional Blend...|
# +-------+-----------------+------------------+-----------------+---------------+------------------+------------------+----------------+----------------+--------------------+

# %% [markdown]
# #Handling Missing and Duplicate Values

# %%
# Missing values
from pyspark.sql.functions import col

df.filter(
    col("transaction_id").isNull()| col("transaction_date").isNull() | col("transaction_time").isNull()| col("transaction_qty").isNull()| col("store_id").isNull()| col("store_location").isNull()| col("product_id").isNull()| col("unit_price").isNull()  | col("product_category").isNull()| col("product_type").isNull()| col("product_detail").isNull()
).show()
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+----------------+-----------------+--------------------+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|product_category|     product_type|      product_detail|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+----------------+-----------------+--------------------+
# |            13|            null|2024-08-14 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|             Tea| Brewed Black tea|        Earl Grey Lg|
# |            14|      2023-01-01|2024-08-14 07:48:19|              1|       5|           null|        57|       3.1|             Tea|  Brewed Chai tea|Spicy Eye Opener ...|
# |            15|      2023-01-01|2024-08-14 07:52:36|              2|       5|Lower Manhattan|        87|      null|            null| Barista Espresso|Ouro Brasileiro shot|
# |            16|      2023-01-01|2024-08-14 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|             Tea|             null|Serenity Green Te...|
# |            17|      2023-01-01|2024-08-14 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|          Bakery|            Scone|                null|
# |            18|      2023-01-01|2024-08-14 08:00:18|              1|       8|           null|        42|       2.5|             Tea|Brewed herbal tea|      Lemon Grass Rg|
# |            13|            null|2024-08-14 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|             Tea| Brewed Black tea|        Earl Grey Lg|
# |            14|      2023-01-01|2024-08-14 07:48:19|              1|       5|           null|        57|       3.1|             Tea|  Brewed Chai tea|Spicy Eye Opener ...|
# |            15|      2023-01-01|2024-08-14 07:52:36|              2|       5|Lower Manhattan|        87|      null|            null| Barista Espresso|Ouro Brasileiro shot|
# |            16|      2023-01-01|2024-08-14 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|             Tea|             null|Serenity Green Te...|
# |            17|      2023-01-01|2024-08-14 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|          Bakery|            Scone|                null|
# |            18|      2023-01-01|2024-08-14 08:00:18|              1|       8|           null|        42|       2.5|             Tea|Brewed herbal tea|      Lemon Grass Rg|
# |            13|            null|2024-08-14 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|             Tea| Brewed Black tea|        Earl Grey Lg|
# |            14|      2023-01-01|2024-08-14 07:48:19|              1|       5|           null|        57|       3.1|             Tea|  Brewed Chai tea|Spicy Eye Opener ...|
# |            15|      2023-01-01|2024-08-14 07:52:36|              2|       5|Lower Manhattan|        87|      null|            null| Barista Espresso|Ouro Brasileiro shot|
# |            16|      2023-01-01|2024-08-14 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|             Tea|             null|Serenity Green Te...|
# |            17|      2023-01-01|2024-08-14 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|          Bakery|            Scone|                null|
# |            18|      2023-01-01|2024-08-14 08:00:18|              1|       8|           null|        42|       2.5|             Tea|Brewed herbal tea|      Lemon Grass Rg|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+----------------+-----------------+--------------------+

# %%
# Alternative code for checking null values
from pyspark.sql.functions import col
from functools import reduce

# Build the condition dynamically
null_condition = reduce(lambda x, y: x | y, [col(c).isNull() for c in df.columns])

# Filter the DataFrame based on the condition
df.filter(null_condition).count()
# Out:
# Out[6]: 18

# %%
df.filter(null_condition).show()
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+----------------+-----------------+--------------------+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|product_category|     product_type|      product_detail|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+----------------+-----------------+--------------------+
# |            13|            null|2024-08-14 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|             Tea| Brewed Black tea|        Earl Grey Lg|
# |            14|      2023-01-01|2024-08-14 07:48:19|              1|       5|           null|        57|       3.1|             Tea|  Brewed Chai tea|Spicy Eye Opener ...|
# |            15|      2023-01-01|2024-08-14 07:52:36|              2|       5|Lower Manhattan|        87|      null|            null| Barista Espresso|Ouro Brasileiro shot|
# |            16|      2023-01-01|2024-08-14 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|             Tea|             null|Serenity Green Te...|
# |            17|      2023-01-01|2024-08-14 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|          Bakery|            Scone|                null|
# |            18|      2023-01-01|2024-08-14 08:00:18|              1|       8|           null|        42|       2.5|             Tea|Brewed herbal tea|      Lemon Grass Rg|
# |            13|            null|2024-08-14 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|             Tea| Brewed Black tea|        Earl Grey Lg|
# |            14|      2023-01-01|2024-08-14 07:48:19|              1|       5|           null|        57|       3.1|             Tea|  Brewed Chai tea|Spicy Eye Opener ...|
# |            15|      2023-01-01|2024-08-14 07:52:36|              2|       5|Lower Manhattan|        87|      null|            null| Barista Espresso|Ouro Brasileiro shot|
# |            16|      2023-01-01|2024-08-14 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|             Tea|             null|Serenity Green Te...|
# |            17|      2023-01-01|2024-08-14 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|          Bakery|            Scone|                null|
# |            18|      2023-01-01|2024-08-14 08:00:18|              1|       8|           null|        42|       2.5|             Tea|Brewed herbal tea|      Lemon Grass Rg|
# |            13|            null|2024-08-14 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|             Tea| Brewed Black tea|        Earl Grey Lg|
# |            14|      2023-01-01|2024-08-14 07:48:19|              1|       5|           null|        57|       3.1|             Tea|  Brewed Chai tea|Spicy Eye Opener ...|
# |            15|      2023-01-01|2024-08-14 07:52:36|              2|       5|Lower Manhattan|        87|      null|            null| Barista Espresso|Ouro Brasileiro shot|
# |            16|      2023-01-01|2024-08-14 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|             Tea|             null|Serenity Green Te...|
# |            17|      2023-01-01|2024-08-14 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|          Bakery|            Scone|                null|
# |            18|      2023-01-01|2024-08-14 08:00:18|              1|       8|           null|        42|       2.5|             Tea|Brewed herbal tea|      Lemon Grass Rg|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+----------------+-----------------+--------------------+

# %%
df= df.dropna()

# %%
# Missing values
from pyspark.sql.functions import col

df.filter(
    col("transaction_id").isNull()| col("transaction_date").isNull() | col("transaction_time").isNull()| col("transaction_qty").isNull()| col("store_id").isNull()| col("store_location").isNull()| col("product_id").isNull()| col("unit_price").isNull()  | col("product_category").isNull()| col("product_type").isNull()| col("product_detail").isNull()
).show()
# Out:
# +--------------+----------------+----------------+---------------+--------+--------------+----------+----------+----------------+------------+--------------+
# |transaction_id|transaction_date|transaction_time|transaction_qty|store_id|store_location|product_id|unit_price|product_category|product_type|product_detail|
# +--------------+----------------+----------------+---------------+--------+--------------+----------+----------+----------------+------------+--------------+
# +--------------+----------------+----------------+---------------+--------+--------------+----------+----------+----------------+------------+--------------+

# %% [markdown]
# # To Check the Duplicate values

# %%
from pyspark.sql.functions import count
# Step 1: Group by all columns and count occurrences
duplicates = df.groupBy(df.columns).count()

# Step 2: Filter rows where count > 1 (these are duplicates)
duplicate_rows = duplicates.filter("count > 1")

# Step 3: Show duplicate rows (optional, to see which rows are duplicated)
duplicate_rows.show()

# Step 4: Count the number of duplicate rows
duplicate_count = duplicate_rows.selectExpr("sum(count - 1) as TotalDuplicates").collect()[0]["TotalDuplicates"]

print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|  product_category|        product_type|      product_detail|count|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----+
# |            60|      2023-01-01|2024-08-14 09:29:56|              1|       8| Hell's Kitchen|        74|       3.5|            Bakery|            Biscotti|     Ginger Biscotti|    3|
# |           550|      2023-01-01|2024-08-14 19:58:52|              1|       3|        Astoria|        39|      4.25|            Coffee|    Barista Espresso|            Latte Rg|    3|
# |           867|      2023-01-02|2024-08-14 14:59:08|              1|       8| Hell's Kitchen|        30|       3.0|            Coffee|Gourmet brewed co...|Columbian Medium ...|    3|
# |           935|      2023-01-02|2024-08-14 16:06:01|              2|       5|Lower Manhattan|        34|      2.45|            Coffee|Premium brewed co...|Jamaican Coffee R...|    3|
# |          1074|      2023-01-02|2024-08-14 18:49:22|              2|       3|        Astoria|        58|       3.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Rg|    3|
# |          1376|      2023-01-03|2024-08-14 14:13:47|              1|       5|Lower Manhattan|        72|      3.25|            Bakery|               Scone|        Ginger Scone|    3|
# |          1742|      2023-01-04|2024-08-14 09:23:19|              1|       8| Hell's Kitchen|        44|       2.5|               Tea|   Brewed herbal tea|       Peppermint Rg|    3|
# |          1961|      2023-01-04|2024-08-14 14:43:05|              2|       8| Hell's Kitchen|        26|       3.0|            Coffee|Organic brewed co...|        Brazilian Rg|    3|
# |          2009|      2023-01-04|2024-08-14 15:29:46|              1|       5|Lower Manhattan|        61|      4.75|Drinking Chocolate|       Hot chocolate|Sustainably Grown...|    3|
# |          2089|      2023-01-04|2024-08-14 17:30:15|              1|       5|Lower Manhattan|        42|       2.5|               Tea|   Brewed herbal tea|      Lemon Grass Rg|    3|
# |          2153|      2023-01-04|2024-08-14 18:55:51|              2|       8| Hell's Kitchen|        51|       3.0|               Tea|    Brewed Black tea|        Earl Grey Lg|    3|
# |          2292|      2023-01-05|2024-08-14 10:40:06|              1|       8| Hell's Kitchen|        35|       3.1|            Coffee|Premium brewed co...|Jamaican Coffee R...|    3|
# |          2346|      2023-01-05|2024-08-14 11:51:32|              1|       5|Lower Manhattan|        87|       3.0|            Coffee|    Barista Espresso|Ouro Brasileiro shot|    3|
# |          2404|      2023-01-05|2024-08-14 12:45:56|              1|       3|        Astoria|        52|       2.5|               Tea|     Brewed Chai tea|Traditional Blend...|    3|
# |          2471|      2023-01-05|2024-08-14 14:01:39|              1|       8| Hell's Kitchen|        44|       2.5|               Tea|   Brewed herbal tea|       Peppermint Rg|    3|
# |          2747|      2023-01-06|2024-08-14 07:05:49|              1|       5|Lower Manhattan|        71|      3.75|            Bakery|              Pastry| Chocolate Croissant|    3|
# |          2806|      2023-01-06|2024-08-14 08:57:28|              2|       8| Hell's Kitchen|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|    3|
# |          2874|      2023-01-06|2024-08-14 11:22:26|              1|       5|Lower Manhattan|        74|       3.5|            Bakery|            Biscotti|     Ginger Biscotti|    3|
# |          2906|      2023-01-06|2024-08-14 12:06:24|              1|       3|        Astoria|        69|      3.25|            Bakery|            Biscotti|   Hazelnut Biscotti|    3|
# |          2946|      2023-01-06|2024-08-14 12:59:23|              2|       5|Lower Manhattan|        43|       3.0|               Tea|   Brewed herbal tea|      Lemon Grass Lg|    3|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----+
# only showing top 20 rows
#
# Number of duplicate rows: 298268

# %%
df = df.dropDuplicates()

# %%
# Step 1: Group by all columns and count occurrences
duplicates = df.groupBy(df.columns).count()

# Step 2: Filter rows where count > 1 (these are duplicates)
duplicate_rows = duplicates.filter("count > 1")

# Step 3: Show duplicate rows (optional, to see which rows are duplicated)
duplicate_rows.show()

# Step 4: Count the number of duplicate rows
duplicate_count = duplicate_rows.selectExpr("sum(count - 1) as TotalDuplicates").collect()[0]["TotalDuplicates"]

print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# +--------------+----------------+----------------+---------------+--------+--------------+----------+----------+----------------+------------+--------------+-----+
# |transaction_id|transaction_date|transaction_time|transaction_qty|store_id|store_location|product_id|unit_price|product_category|product_type|product_detail|count|
# +--------------+----------------+----------------+---------------+--------+--------------+----------+----------+----------------+------------+--------------+-----+
# +--------------+----------------+----------------+---------------+--------+--------------+----------+----------+----------------+------------+--------------+-----+
#
# Number of duplicate rows: None

# %%
df.describe().show()
# Out:
# +-------+-----------------+------------------+-----------------+---------------+------------------+------------------+----------------+----------------+--------------------+
# |summary|   transaction_id|   transaction_qty|         store_id| store_location|        product_id|        unit_price|product_category|    product_type|      product_detail|
# +-------+-----------------+------------------+-----------------+---------------+------------------+------------------+----------------+----------------+--------------------+
# |  count|           149116|            149116|           149116|         149116|            149116|            149116|          149116|          149116|              149116|
# |   mean|74737.37187156308| 1.438276241315486|5.342062555326055|           null| 47.91860699053086|3.3822194130743495|            null|            null|                null|
# | stddev|43153.60001591792|0.5425087647372187|2.074240591571703|           null|17.930020247641586|2.6587226166627147|            null|            null|                null|
# |    min|                1|                 1|                3|        Astoria|                 1|               0.8|          Bakery|Barista Espresso|    Almond Croissant|
# |    max|           149456|                 8|                8|Lower Manhattan|                87|              45.0|             Tea|Sugar free syrup|Traditional Blend...|
# +-------+-----------------+------------------+-----------------+---------------+------------------+------------------+----------------+----------------+--------------------+

# %% [markdown]
# # Explore the frequency of different categories,type and detail

# %%
from pyspark.sql import functions as F

# List of tuples with column name and count of unique values
unique_counts = [(c, df.select(F.col(c)).distinct().count()) for c in df.columns]

# Create a DataFrame from the list of tuples
columnValue = spark.createDataFrame(unique_counts, ["Column_name", "Unique_values"])
columnValue.show()
# Out:
# +----------------+-------------+
# |     Column_name|Unique_values|
# +----------------+-------------+
# |  transaction_id|       149116|
# |transaction_date|          181|
# |transaction_time|        25762|
# | transaction_qty|            6|
# |        store_id|            3|
# |  store_location|            3|
# |      product_id|           80|
# |      unit_price|           41|
# |product_category|            9|
# |    product_type|           29|
# |  product_detail|           80|
# +----------------+-------------+

# %%
# Explore the frequency of different categories
df.groupBy("product_category").count().orderBy("count", ascending=False).show()
# Out:
# +------------------+-----+
# |  product_category|count|
# +------------------+-----+
# |            Coffee|58416|
# |               Tea|45449|
# |            Bakery|22796|
# |Drinking Chocolate|11468|
# |          Flavours| 6790|
# |      Coffee beans| 1753|
# |         Loose Tea| 1210|
# |           Branded|  747|
# |Packaged Chocolate|  487|
# +------------------+-----+

# %%
df.groupBy("product_type").count().orderBy("count", ascending=False).show()
# Out:
# +--------------------+-----+
# |        product_type|count|
# +--------------------+-----+
# |     Brewed Chai tea|17183|
# |Gourmet brewed co...|16912|
# |    Barista Espresso|16403|
# |       Hot chocolate|11468|
# |    Brewed Black tea|11350|
# |   Brewed herbal tea|11245|
# |               Scone|10173|
# |Organic brewed co...| 8489|
# |         Drip coffee| 8477|
# |Premium brewed co...| 8135|
# |              Pastry| 6912|
# |            Biscotti| 5711|
# |    Brewed Green tea| 5671|
# |       Regular syrup| 4979|
# |    Sugar free syrup| 1811|
# |          Housewares|  526|
# |            Chai tea|  443|
# |       Organic Beans|  415|
# |       Gourmet Beans|  366|
# |       Premium Beans|  336|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# # Perform Data Transformation

# %%
# Calculate 'Total Sales'
df = df.withColumn("Total_sales", col("unit_price") * col("transaction_qty"))

df.show()
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|  product_category|        product_type|      product_detail|Total_sales|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+
# |            15|      2023-01-01|2024-08-14 07:52:36|              2|       5|Lower Manhattan|        87|       3.0|            Coffee|    Barista Espresso|Ouro Brasileiro shot|        6.0|
# |            18|      2023-01-01|2024-08-14 08:00:18|              1|       8| Hell's Kitchen|        42|       2.5|               Tea|   Brewed herbal tea|      Lemon Grass Rg|        2.5|
# |             2|      2023-01-01|2024-08-14 07:08:56|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|        6.2|
# |             8|      2023-01-01|2024-08-14 07:33:34|              2|       5|Lower Manhattan|        28|       2.0|            Coffee|Gourmet brewed co...|Columbian Medium ...|        4.0|
# |             1|      2023-01-01|2024-08-14 07:06:11|              2|       5|Lower Manhattan|        32|       3.0|            Coffee|Gourmet brewed co...|         Ethiopia Rg|        6.0|
# |             5|      2023-01-01|2024-08-14 07:22:41|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|        6.2|
# |             3|      2023-01-01|2024-08-14 07:14:04|              2|       5|Lower Manhattan|        59|       4.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Lg|        9.0|
# |             6|      2023-01-01|2024-08-14 07:22:41|              1|       5|Lower Manhattan|        77|       3.0|            Bakery|               Scone|       Oatmeal Scone|        3.0|
# |            13|      2023-01-01|2024-08-14 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|               Tea|    Brewed Black tea|        Earl Grey Lg|        3.0|
# |            19|      2023-01-01|2024-08-14 08:00:39|              2|       8| Hell's Kitchen|        59|       4.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Lg|        9.0|
# |            17|      2023-01-01|2024-08-14 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|            Bakery|               Scone|  Jumbo Savory Scone|       3.75|
# |            21|      2023-01-01|2024-08-14 08:17:27|              2|       8| Hell's Kitchen|        33|       3.5|            Coffee|Gourmet brewed co...|         Ethiopia Lg|        7.0|
# |            16|      2023-01-01|2024-08-14 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|               Tea|    Brewed Green tea|Serenity Green Te...|        6.0|
# |            10|      2023-01-01|2024-08-14 07:39:34|              2|       5|Lower Manhattan|        58|       3.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Rg|        7.0|
# |             9|      2023-01-01|2024-08-14 07:39:13|              1|       5|Lower Manhattan|        39|      4.25|            Coffee|    Barista Espresso|            Latte Rg|       4.25|
# |             7|      2023-01-01|2024-08-14 07:25:49|              1|       5|Lower Manhattan|        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|        2.0|
# |            11|      2023-01-01|2024-08-14 07:43:05|              1|       5|Lower Manhattan|        56|      2.55|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|       2.55|
# |            20|      2023-01-01|2024-08-14 08:11:45|              1|       8| Hell's Kitchen|        61|      4.75|Drinking Chocolate|       Hot chocolate|Sustainably Grown...|       4.75|
# |             4|      2023-01-01|2024-08-14 07:20:24|              1|       5|Lower Manhattan|        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|        2.0|
# |            14|      2023-01-01|2024-08-14 07:48:19|              1|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|        3.1|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql import functions as F

# Assuming 'transaction_date' is in string format, convert it to DateType
df = df.withColumn("transaction_date", F.to_date(F.col("transaction_date"), "dd/MM/yyyy"))
df = df.withColumn("transaction_time", F.col("transaction_time").cast("timestamp"))
df.show()
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|  product_category|        product_type|      product_detail|Total_sales|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+
# |            15|      2023-01-01|2024-08-14 07:52:36|              2|       5|Lower Manhattan|        87|       3.0|            Coffee|    Barista Espresso|Ouro Brasileiro shot|        6.0|
# |            18|      2023-01-01|2024-08-14 08:00:18|              1|       8| Hell's Kitchen|        42|       2.5|               Tea|   Brewed herbal tea|      Lemon Grass Rg|        2.5|
# |             2|      2023-01-01|2024-08-14 07:08:56|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|        6.2|
# |             8|      2023-01-01|2024-08-14 07:33:34|              2|       5|Lower Manhattan|        28|       2.0|            Coffee|Gourmet brewed co...|Columbian Medium ...|        4.0|
# |             1|      2023-01-01|2024-08-14 07:06:11|              2|       5|Lower Manhattan|        32|       3.0|            Coffee|Gourmet brewed co...|         Ethiopia Rg|        6.0|
# |             5|      2023-01-01|2024-08-14 07:22:41|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|        6.2|
# |             3|      2023-01-01|2024-08-14 07:14:04|              2|       5|Lower Manhattan|        59|       4.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Lg|        9.0|
# |             6|      2023-01-01|2024-08-14 07:22:41|              1|       5|Lower Manhattan|        77|       3.0|            Bakery|               Scone|       Oatmeal Scone|        3.0|
# |            13|      2023-01-01|2024-08-14 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|               Tea|    Brewed Black tea|        Earl Grey Lg|        3.0|
# |            19|      2023-01-01|2024-08-14 08:00:39|              2|       8| Hell's Kitchen|        59|       4.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Lg|        9.0|
# |            17|      2023-01-01|2024-08-14 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|            Bakery|               Scone|  Jumbo Savory Scone|       3.75|
# |            21|      2023-01-01|2024-08-14 08:17:27|              2|       8| Hell's Kitchen|        33|       3.5|            Coffee|Gourmet brewed co...|         Ethiopia Lg|        7.0|
# |            16|      2023-01-01|2024-08-14 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|               Tea|    Brewed Green tea|Serenity Green Te...|        6.0|
# |            10|      2023-01-01|2024-08-14 07:39:34|              2|       5|Lower Manhattan|        58|       3.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Rg|        7.0|
# |             9|      2023-01-01|2024-08-14 07:39:13|              1|       5|Lower Manhattan|        39|      4.25|            Coffee|    Barista Espresso|            Latte Rg|       4.25|
# |             7|      2023-01-01|2024-08-14 07:25:49|              1|       5|Lower Manhattan|        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|        2.0|
# |            11|      2023-01-01|2024-08-14 07:43:05|              1|       5|Lower Manhattan|        56|      2.55|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|       2.55|
# |            20|      2023-01-01|2024-08-14 08:11:45|              1|       8| Hell's Kitchen|        61|      4.75|Drinking Chocolate|       Hot chocolate|Sustainably Grown...|       4.75|
# |             4|      2023-01-01|2024-08-14 07:20:24|              1|       5|Lower Manhattan|        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|        2.0|
# |            14|      2023-01-01|2024-08-14 07:48:19|              1|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|        3.1|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- transaction_id: integer (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_time: timestamp (nullable = true)
#  |-- transaction_qty: integer (nullable = true)
#  |-- store_id: integer (nullable = true)
#  |-- store_location: string (nullable = true)
#  |-- product_id: integer (nullable = true)
#  |-- unit_price: double (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- product_type: string (nullable = true)
#  |-- product_detail: string (nullable = true)
#  |-- Total_sales: double (nullable = true)

# %%
# Add a new column 'year' extracted from 'transaction_date'
df = df.withColumn("year", F.year(F.col("transaction_date")))

# Add a new column 'month' extracted from 'transaction_date'
df = df.withColumn("month", F.date_format(F.col("transaction_date"), "MMMM"))

# Add a new column 'day' extracted from 'transaction_date'
df = df.withColumn("day", F.date_format(F.col("transaction_date"), "EEEE"))

df.show()
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+----+-------+---------+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|  product_category|        product_type|      product_detail|Total_sales|year|  month|      day|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------

# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+----+-------+---------+
# only showing top 20 rows

# %%
# Get unique values in the 'year' ,'month','day'column
unique_year = df.select("year").distinct().show()
unique_month = df.select("month").distinct().show()
unique_day = df.select("day").distinct().show()
unique_product_category = df.select("product_category").distinct().show()
unique_store_location = df.select("store_location").distinct().show()
# Out:
# +----+
# |year|
# +----+
# |2023|
# +----+
#
# +--------+
# |   month|
# +--------+
# |February|
# | January|
# |   March|
# |   April|
# |     May|
# |    June|
# +--------+
#
# +---------+
# |      day|
# +---------+
# |Wednesday|
# |  Tuesday|
# |   Friday|
# | Thursday|
# | Saturday|
# |   Monday|
# |   Sunday|
# +---------+
#
# +------------------+
# |  product_category|
# +------------------+
# |            Bakery|
# |         Loose Tea|
# |Drinking Chocolate|
# |               Tea|
# |           Branded|
# |            Coffee|
# |      Coffee beans|
# |Packaged Chocolate|
# |          Flavours|
# +------------------+
#
# +---------------+
# | store_location|
# +---------------+
# |Lower Manhattan|
# | Hell's Kitchen|
# |        Astoria|
# +---------------+

# %%
# Add a new column 'hour' extracted from 'transaction_time'
df = df.withColumn("hour", F.hour(F.col("transaction_time")))

# Add a new column 'hour' extracted from 'transaction_time'
df = df.withColumn("minute", F.minute(F.col("transaction_time")))

# Add a new column 'hour' extracted from 'transaction_time'
df = df.withColumn("second", F.second(F.col("transaction_time")))

# Show the updated DataFrame
df.show()
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+----+-------+---------+----+------+------+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|  product_category|        product_type|      product_detail|Total_sales|year|  month|      day|hour|minute|second|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+----+-------+---------+----+------+------+
# |           662|      2023-01-02|2024-08-14 11:14:15|              2|       3|        Astoria|        32|       3.0|            Coffee|Gourmet brewed co...|         Ethiopia Rg|        6.0|2023|January|   Monday|  11|    14|    15|
# |           729|      2023-01-02|2024-08-14 12:26:13|              2|       5|Lower Manhattan|        25|       2.2|            Coffee|Organic brewed co...|        Brazilian Sm|        4.4|2023|January|   Monday|  12|    26|    13|
# |           838|      2023-01-02|2024-08-14 14:21:55|              2|       8| Hell's Kitchen|        41|      4.25|            Coffee|    Barista Espresso|       Cappuccino Lg|        8.5|2023|January|   Monday|  14|    21|    55|
# |           866|      2023-01-02|2024-08-14 14:58:28|              2|       8| Hell's Kitchen|        46|       2.5|               Tea|    Brewed Green tea|Serenity Green Te...|        5.0|2023|January|   Monday|  14|    58|    28|
# |           881|      2023-01-02|2024-08-14 15:22:19|              2|       8| Hell's Kitchen|        28|       2.0|            Coffee|Gourmet brewed co...|Columbian Medium ...|        4.0|2023|January|   Monday|  15|    22|    19|
# |          1429|      2023-01-03|2024-08-14 14:57:49|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...
it 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>transaction_id</th><th>transaction_date</th><th>transaction_time</th><th>transaction_qty</th><th>store_id</th><th>store_location</th><th>product_id</th><th>unit_price</th><th>product_category</th><th>product_type</th><th>product_detail</th><th>Total_sales</th><th>year</th><th>month</th><th>day</th><th>hour</th><th>minute</th><th>second</th></tr></thead><tbody><tr><td>662</td><td>2023-01-02</td><td>2024-08-14T11:14:15.000+0000</td><td>2</td><td>3</td><td>Astoria</td><td>32</td><td>3.0</td><td>Coffee</td><td>Gourmet brewed coffee</td><td>Ethiopia Rg</td><td>6.0</td><td>2023</td><td>January</td><td>Monday</td><td>11</td><td>14</td><td>15</td></tr><tr><td>729</td><td>2023-01-02</td><td>2024-08-14T12:26:13.000+0000</td><td>2</td><td>5</td><td>Lower Manhattan</td><td>25</td><td>2.2</td><td>Coffee</td><td>Organic brewed coffee</td><td>Brazilian Sm</td><td>4.4</td><td>2023</td><td>January</td><td>Monday</td><td>12</td><td>26</td><td>13</td></tr><tr><td>838</td><td>2023-01-02</td><td>2024-08-14T14:21:55.000+0000</td><td>2</td><td>8</td><td>Hell's Kitchen</td><td>41</td><td>4.25</td><td>Coffee</td><td>Barista Espresso</td><td>Cappuccino Lg</td><td>8.5</td><td>2023</td><td>January</td><td>Monday</td><td>14</td><td>21</td><td>55</td></tr><tr><td>866</td><td>2023-01-02</td><td>2024-08-14T14:58:28.000+0000</td><td>2</td><td>8</td><td>Hell's Kitchen</td><td>46</td><td>2.5</td><td>Tea</td><td>Brewed Green tea</td><td>Serenity Green Tea Rg</td><td>5.0</td><td>2023</td><td>January</td><td>Monday</td><td>14</td><td>58</td><td>28</td></tr><tr><td>881</td><td>2023-01-02</td><td>2024-08-14T15:22:19.000+0000</td><td>2</td><td>8</td><td>Hell's Kitchen</td><td>28</td><td>2.0</td><td>Coffee</td><td>Gourmet brewed coffee</td><td>Columbian Medium Roast Sm</td><td>4.0</td><td>2023</td><td>January</td><td>Monday</td><td>15</td><td>22</td><td>19</td></tr></tbody></table></div>

# %%
distinct_values_list = [row.store_location for row in df.select("store_location").distinct().collect()]

# %%
# %python
# Create the a dropdown widget
dbutils.widgets.dropdown(name='store_location', defaultValue='Astoria', choices=distinct_values_list , label='Dropdown')

# %%
# %sql 
-- Total sales by product category
select product_category,Total_sales from Coffee_data
-- Highest sales is are Coffee then 2nd highest sales Tea and 3rd hightest bakery
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_category</th><th>Total_sales</th></tr></thead><tbody><tr><td>Coffee</td><td>6.0</td></tr><tr><td>Coffee</td><td>4.4</td></tr><tr><td>Coffee</td><td>8.5</td></tr><tr><td>Tea</td><td>5.0</td></tr><tr><td>Coffee</td><td>4.0</td></tr><tr><td>Tea</td><td>6.2</td></tr><tr><td>Drinking Chocolate</td><td>9.0</td></tr><tr><td>Tea</td><td>3.0</td></tr><tr><td>Coffee</td><td>4.25</td></tr><tr><td>Bakery</td><td>3.0</td></tr><tr><td>Coffee</td><td>4.0</td></tr><tr><td>Coffee</td><td>8.5</td></tr><tr><td>Coffee</td><td>6.2</td></tr><tr><td
</td><td>3.75</td></tr><tr><td>Coffee</td><td>3.0</td></tr><tr><td>Coffee</td><td>6.0</td></tr><tr><td>Coffee</td><td>3.1</td></tr><tr><td>Tea</td><td>2.5</td></tr><tr><td>Coffee</td><td>4.4</td></tr><tr><td>Coffee</td><td>7.0</td></tr><tr><td>Tea</td><td>3.0</td></tr><tr><td>Coffee</td><td>3.0</td></tr><tr><td>Bakery</td><td>3.75</td></tr><tr><td>Tea</td><td>4.0</td></tr><tr><td>Drinking Chocolate</td><td>3.5</td></tr><tr><td>Tea</td><td>2.55</td></tr><tr><td>Coffee</td><td>3.75</td></tr><tr><td>Tea</td><td>3.0</td></tr><tr><td>Coffee</td><td>3.0</td></tr><tr><td>Bakery</td><td>3.75</td></tr><tr><td>Coffee</td><td>7.5</td></tr><tr><td>Tea</td><td>2.5</td></tr><tr><td>Bakery</td><td>3.75</td></tr><tr><td>Coffee</td><td>3.0</td></tr><tr><td>Tea</td><td>5.0</td></tr><tr><td>Tea</td><td>5.0</td></tr><tr><td>Coffee beans</td><td>20.45</td></tr><tr><td>Tea</td><td>2.5</td></tr><tr><td>Drinking Chocolate</td><td>9.5</td></tr><tr><td>Tea</td><td>5.0</td></tr>< ...
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
-- Top 5 Total_sales by product detail
select product_type,sum(Total_sales) as Total_sales from Coffee_data group by product_type order by Total_sales desc limit 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_type</th><th>Total_sales</th></tr></thead><tbody><tr><td>Barista Espresso</td><td>91406.20000000013</td></tr><tr><td>Brewed Chai tea</td><td>77081.9500000005</td></tr><tr><td>Hot chocolate</td><td>72416.0</td></tr><tr><td>Gourmet brewed coffee</td><td>70034.59999999967</td></tr><tr><td>Brewed Black tea</td><td>47932.0</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
-- Lowest 5 Total_sales by product detail
select product_type,sum(Total_sales) as Total_sales from Coffee_data group by product_type order by Total_sales limit 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_type</th><th>Total_sales</th></tr></thead><tbody><tr><td>Green beans</td><td>1340.0</td></tr><tr><td>Green tea</td><td>1470.75</td></tr><tr><td>Organic Chocolate</td><td>1679.5999999999992</td></tr><tr><td>Sugar free syrup</td><td>2324.000000000004</td></tr><tr><td>Black tea</td><td>2711.8499999999985</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
-- product type vs Total Quantity sold
-- Top 10
select product_type,store_location,sum(transaction_qty) as `Total_qty` from Coffee_data group by product_type,store_location order by Total_qty desc limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_type</th><th>store_location</th><th>Total_qty</th></tr></thead><tbody><tr><td>Brewed Chai tea</td><td>Astoria</td><td>9306</td></tr><tr><td>Barista Espresso</td><td>Hell's Kitchen</td><td>9064</td></tr><tr><td>Gourmet brewed coffee</td><td>Astoria</td><td>8938</td></tr><tr><td>Brewed Chai tea</td><td>Hell's Kitchen</td><td>8755</td></tr><tr><td>Gourmet brewed coffee</td><td>Lower Manhattan</td><td>8563</td></tr><tr><td>Barista Espresso</td><td>Lower Manhattan</td><td>8534</td></tr><tr><td>Gourmet brewed coffee</td><td>Hell's Kitchen</td><td>8472</td></tr><tr><td>Brewed Chai tea</td><td>Lower Manhattan</td><td>8189</td></tr><tr><td>Barista Espresso</td><td>Astoria</td><td>7345</td></tr><tr><td>Hot chocolate</td><td>Astoria</td><td>6351</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
-