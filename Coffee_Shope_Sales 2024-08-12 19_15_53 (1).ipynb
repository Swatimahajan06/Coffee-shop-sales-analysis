# %%
# %fs ls
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/</td><td>FileStore/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-datasets/</td><td>databricks-datasets/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/databricks-results/</td><td>databricks-results/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/user/</td><td>user/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# %fs ls dbfs:/FileStore/
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/</td><td>tables/</td><td>0</td><td>0</td></tr></tbody></table></div>

# %%
# Import necessary libraries
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("coffee_Shop_sales_analysis") \
    .getOrCreate()


df = spark.read.csv("dbfs:/FileStore/tables/", header=True, inferSchema=True)

df.show(5)
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|  product_category|        product_type|      product_detail|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+
# |             1|      2023-01-01|2024-08-22 07:06:11|              2|       5|Lower Manhattan|        32|       3.0|            Coffee|Gourmet brewed co...|         Ethiopia Rg|
# |             2|      2023-01-01|2024-08-22 07:08:56|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|
# |             3|      2023-01-01|2024-08-22 07:14:04|              2|       5|Lower Manhattan|        59|       4.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Lg|
# |             4|      2023-01-01|2024-08-22 07:20:24|              1|       5|Lower Manhattan|        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|
# |             5|      2023-01-01|2024-08-22 07:22:41|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
df.take(5)
# Out:
# Out[3]: [Row(transaction_id=1, transaction_date=datetime.date(2023, 1, 1), transaction_time=datetime.datetime(2024, 8, 22, 7, 6, 11), transaction_qty=2, store_id=5, store_location='Lower Manhattan', product_id=32, unit_price=3.0, product_category='Coffee', product_type='Gourmet brewed coffee', product_detail='Ethiopia Rg'),
#  Row(transaction_id=2, transaction_date=datetime.date(2023, 1, 1), transaction_time=datetime.datetime(2024, 8, 22, 7, 8, 56), transaction_qty=2, store_id=5, store_location='Lower Manhattan', product_id=57, unit_price=3.1, product_category='Tea', product_type='Brewed Chai tea', product_detail='Spicy Eye Opener Chai Lg'),
#  Row(transaction_id=3, transaction_date=datetime.date(2023, 1, 1), transaction_time=datetime.datetime(2024, 8, 22, 7, 14, 4), transaction_qty=2, store_id=5, store_location='Lower Manhattan', product_id=59, unit_price=4.5, product_category='Drinking Chocolate', product_type='Hot chocolate', product_detail='Dark chocolate Lg'),
#  Row(transaction_id=4, transaction_date=datetime.date(2023, 1, 1), transaction_time=datetime.datetime(2024, 8, 22, 7, 20, 24), transaction_qty=1, store_id=5, store_location='Lower Manhattan', product_id=22, unit_price=2.0, product_category='Coffee', product_type='Drip coffee', product_detail='Our Old Time Diner Blend Sm'),
#  Row(transaction_id=5, transaction_date=datetime.date(2023, 1, 1), transaction_time=datetime.datetime(2024, 8, 22, 7, 22, 41), transaction_qty=2, store_id=5, store_location='Lower Manhattan', product_id=57, unit_price=3.1, product_category='Tea', product_type='Brewed Chai tea', product_detail='Spicy Eye Opener Chai Lg')]

# %%
# Number of rows
num_rows = df.count()

# Number of columns
num_columns = len(df.columns)

# Print the shape of the DataFrame
print(f"Shape: ({num_rows}, {num_columns})")
# Out:
# Shape: (447402, 11)

# %%
# Print the schema of the DataFrame (data types of each column)
df.printSchema()

# Show summary statistics (e.g., count, mean, stddev, min, max) for numeric columns
df.describe().show()
# Out:
# root
#  |-- transaction_id: integer (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_time: timestamp (nullable = true)
#  |-- transaction_qty: integer (nullable = true)
#  |-- store_id: integer (nullable = true)
#  |-- store_location: string (nullable = true)
#  |-- product_id: integer (nullable = true)
#  |-- unit_price: double (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- product_type: string (nullable = true)
#  |-- product_detail: string (nullable = true)
#
# +-------+-----------------+------------------+-----------------+---------------+------------------+------------------+----------------+----------------+--------------------+
# |summary|   transaction_id|   transaction_qty|         store_id| store_location|        product_id|        unit_price|product_category|    product_type|      product_detail|
# +-------+-----------------+------------------+-----------------+---------------+------------------+------------------+----------------+----------------+--------------------+
# |  count|           447402|            447402|           447402|         447396|            447402|            447399|          447399|          447399|              447399|
# |   mean|74728.35245483927|1.4382836911770622|5.342041385599528|           null| 47.91887832419167| 3.382181542649976|            null|            null|                null|
# | stddev|43158.70741237079|0.5425030462067035|2.074125408677048|           null|17.930060710265444|2.6585779841355572|            null|            null|                null|
# |    min|                1|                 1|                3|        Astoria|                 1|               0.8|          Bakery|Barista Espresso|    Almond Croissant|
# |    max|           149456|                 8|                8|Lower Manhattan|                87|              45.0|             Tea|Sugar free syrup|Traditional Blend...|
# +-------+-----------------+------------------+-----------------+---------------+------------------+------------------+----------------+----------------+--------------------+

# %% [markdown]
# #Handling Missing and Duplicate Values

# %%
# Missing values
from pyspark.sql.functions import col

df.filter(
    col("transaction_id").isNull()| col("transaction_date").isNull() | col("transaction_time").isNull()| col("transaction_qty").isNull()| col("store_id").isNull()| col("store_location").isNull()| col("product_id").isNull()| col("unit_price").isNull()  | col("product_category").isNull()| col("product_type").isNull()| col("product_detail").isNull()
).show()
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+----------------+-----------------+--------------------+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|product_category|     product_type|      product_detail|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+----------------+-----------------+--------------------+
# |            13|            null|2024-08-22 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|             Tea| Brewed Black tea|        Earl Grey Lg|
# |            14|      2023-01-01|2024-08-22 07:48:19|              1|       5|           null|        57|       3.1|             Tea|  Brewed Chai tea|Spicy Eye Opener ...|
# |            15|      2023-01-01|2024-08-22 07:52:36|              2|       5|Lower Manhattan|        87|      null|            null| Barista Espresso|Ouro Brasileiro shot|
# |            16|      2023-01-01|2024-08-22 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|             Tea|             null|Serenity Green Te...|
# |            17|      2023-01-01|2024-08-22 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|          Bakery|            Scone|                null|
# |            18|      2023-01-01|2024-08-22 08:00:18|              1|       8|           null|        42|       2.5|             Tea|Brewed herbal tea|      Lemon Grass Rg|
# |            13|            null|2024-08-22 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|             Tea| Brewed Black tea|        Earl Grey Lg|
# |            14|      2023-01-01|2024-08-22 07:48:19|              1|       5|           null|        57|       3.1|             Tea|  Brewed Chai tea|Spicy Eye Opener ...|
# |            15|      2023-01-01|2024-08-22 07:52:36|              2|       5|Lower Manhattan|        87|      null|            null| Barista Espresso|Ouro Brasileiro shot|
# |            16|      2023-01-01|2024-08-22 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|             Tea|             null|Serenity Green Te...|
# |            17|      2023-01-01|2024-08-22 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|          Bakery|            Scone|                null|
# |            18|      2023-01-01|2024-08-22 08:00:18|              1|       8|           null|        42|       2.5|             Tea|Brewed herbal tea|      Lemon Grass Rg|
# |            13|            null|2024-08-22 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|             Tea| Brewed Black tea|        Earl Grey Lg|
# |            14|      2023-01-01|2024-08-22 07:48:19|              1|       5|           null|        57|       3.1|             Tea|  Brewed Chai tea|Spicy Eye Opener ...|
# |            15|      2023-01-01|2024-08-22 07:52:36|              2|       5|Lower Manhattan|        87|      null|            null| Barista Espresso|Ouro Brasileiro shot|
# |            16|      2023-01-01|2024-08-22 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|             Tea|             null|Serenity Green Te...|
# |            17|      2023-01-01|2024-08-22 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|          Bakery|            Scone|                null|
# |            18|      2023-01-01|2024-08-22 08:00:18|              1|       8|           null|        42|       2.5|             Tea|Brewed herbal tea|      Lemon Grass Rg|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+----------------+-----------------+--------------------+

# %%
df= df.dropna()

# %%
# Missing values
from pyspark.sql.functions import col

df.filter(
    col("transaction_id").isNull()| col("transaction_date").isNull() | col("transaction_time").isNull()| col("transaction_qty").isNull()| col("store_id").isNull()| col("store_location").isNull()| col("product_id").isNull()| col("unit_price").isNull()  | col("product_category").isNull()| col("product_type").isNull()| col("product_detail").isNull()
).show()
# Out:
# +--------------+----------------+----------------+---------------+--------+--------------+----------+----------+----------------+------------+--------------+
# |transaction_id|transaction_date|transaction_time|transaction_qty|store_id|store_location|product_id|unit_price|product_category|product_type|product_detail|
# +--------------+----------------+----------------+---------------+--------+--------------+----------+----------+----------------+------------+--------------+
# +--------------+----------------+----------------+---------------+--------+--------------+----------+----------+----------------+------------+--------------+

# %% [markdown]
# # To Check the Duplicate values

# %%
from pyspark.sql.functions import count
# Step 1: Group by all columns and count occurrences
duplicates = df.groupBy(df.columns).count()

# Step 2: Filter rows where count > 1 (these are duplicates)
duplicate_rows = duplicates.filter("count > 1")

# Step 3: Show duplicate rows (optional, to see which rows are duplicated)
duplicate_rows.show()

# Step 4: Count the number of duplicate rows
duplicate_count = duplicate_rows.selectExpr("sum(count - 1) as TotalDuplicates").collect()[0]["TotalDuplicates"]

print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|  product_category|        product_type|      product_detail|count|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----+
# |           153|      2023-01-01|2024-08-22 11:57:17|              2|       3|        Astoria|        37|       3.0|            Coffee|    Barista Espresso|       Espresso shot|    3|
# |           287|      2023-01-01|2024-08-22 14:13:28|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|    3|
# |           372|      2023-01-01|2024-08-22 16:03:54|              1|       8| Hell's Kitchen|        46|       2.5|               Tea|    Brewed Green tea|Serenity Green Te...|    3|
# |           911|      2023-01-02|2024-08-22 15:48:55|              1|       5|Lower Manhattan|        73|      3.75|            Bakery|              Pastry|    Almond Croissant|    3|
# |          1160|      2023-01-03|2024-08-22 08:50:21|              2|       8| Hell's Kitchen|        44|       2.5|               Tea|   Brewed herbal tea|       Peppermint Rg|    3|
# |          1493|      2023-01-03|2024-08-22 15:49:11|              1|       5|Lower Manhattan|        59|       4.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Lg|    3|
# |          1496|      2023-01-03|2024-08-22 15:53:19|              1|       3|        Astoria|        56|      2.55|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|    3|
# |          1509|      2023-01-03|2024-08-22 16:08:18|              1|       8| Hell's Kitchen|        47|       3.0|               Tea|    Brewed Green tea|Serenity Green Te...|    3|
# |          1727|      2023-01-04|2024-08-22 08:42:10|              2|       5|Lower Manhattan|        28|       2.0|            Coffee|Gourmet brewed co...|Columbian Medium ...|    3|
# |          1953|      2023-01-04|2024-08-22 14:37:07|              1|       5|Lower Manhattan|        34|      2.45|            Coffee|Premium brewed co...|Jamaican Coffee R...|    3|
# |          2264|      2023-01-05|2024-08-22 09:38:01|              1|       5|Lower Manhattan|        72|      3.25|            Bakery|               Scone|        Ginger Scone|    3|
# |          2279|      2023-01-05|2024-08-22 10:20:56|              1|       5|Lower Manhattan|        75|       3.5|            Bakery|              Pastry|           Croissant|    3|
# |          2282|      2023-01-05|2024-08-22 10:27:21|              1|       8| Hell's Kitchen|        29|       2.5|            Coffee|Gourmet brewed co...|Columbian Medium ...|    3|
# |          2328|      2023-01-05|2024-08-22 11:24:27|              1|       3|        Astoria|        45|       3.0|               Tea|   Brewed herbal tea|       Peppermint Lg|    3|
# |          2491|      2023-01-05|2024-08-22 14:31:58|              1|       8| Hell's Kitchen|        58|       3.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Rg|    3|
# |          2914|      2023-01-06|2024-08-22 12:23:31|              1|       3|        Astoria|        71|      3.75|            Bakery|              Pastry| Chocolate Croissant|    3|
# |          3062|      2023-01-06|2024-08-22 15:25:57|              1|       5|Lower Manhattan|        75|       3.5|            Bakery|              Pastry|           Croissant|    3|
# |          3249|      2023-01-06|2024-08-22 19:50:55|              2|       3|        Astoria|        54|       2.5|               Tea|     Brewed Chai tea|Morning Sunrise C...|    3|
# |          4066|      2023-01-08|2024-08-22 10:25:38|              2|       5|Lower Manhattan|        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|    3|
# |          4266|      2023-01-08|2024-08-22 15:16:46|              2|       5|Lower Manhattan|        40|      3.75|            Coffee|    Barista Espresso|          Cappuccino|    3|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----+
# only showing top 20 rows
#
# Number of duplicate rows: 298268

# %%
df = df.dropDuplicates()

# %%
# Step 1: Group by all columns and count occurrences
duplicates = df.groupBy(df.columns).count()

# Step 2: Filter rows where count > 1 (these are duplicates)
duplicate_rows = duplicates.filter("count > 1")

# Step 3: Show duplicate rows (optional, to see which rows are duplicated)
duplicate_rows.show()

# Step 4: Count the number of duplicate rows
duplicate_count = duplicate_rows.selectExpr("sum(count - 1) as TotalDuplicates").collect()[0]["TotalDuplicates"]

print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# +--------------+----------------+----------------+---------------+--------+--------------+----------+----------+----------------+------------+--------------+-----+
# |transaction_id|transaction_date|transaction_time|transaction_qty|store_id|store_location|product_id|unit_price|product_category|product_type|product_detail|count|
# +--------------+----------------+----------------+---------------+--------+--------------+----------+----------+----------------+------------+--------------+-----+
# +--------------+----------------+----------------+---------------+--------+--------------+----------+----------+----------------+------------+--------------+-----+
#
# Number of duplicate rows: None

# %%
df.describe().show()
# Out:
# +-------+-----------------+------------------+------------------+---------------+------------------+------------------+----------------+----------------+--------------------+
# |summary|   transaction_id|   transaction_qty|          store_id| store_location|        product_id|        unit_price|product_category|    product_type|      product_detail|
# +-------+-----------------+------------------+------------------+---------------+------------------+------------------+----------------+----------------+--------------------+
# |  count|           149116|            149116|            149116|         149116|            149116|            149116|          149116|          149116|              149116|
# |   mean|74737.37187156308| 1.438276241315486| 5.342062555326055|           null| 47.91860699053086|3.3822194130743495|            null|            null|                null|
# | stddev|43153.60001591794|0.5425087647372193|2.0742405915716993|           null|17.930020247641586|2.6587226166627165|            null|            null|                null|
# |    min|                1|                 1|                 3|        Astoria|                 1|               0.8|          Bakery|Barista Espresso|    Almond Croissant|
# |    max|           149456|                 8|                 8|Lower Manhattan|                87|              45.0|             Tea|Sugar free syrup|Traditional Blend...|
# +-------+-----------------+------------------+------------------+---------------+------------------+------------------+----------------+----------------+--------------------+

# %% [markdown]
# # Explore the frequency of different categories,type and detail

# %%
from pyspark.sql import functions as F

# List of tuples with column name and count of unique values
unique_counts = [(c, df.select(F.col(c)).distinct().count()) for c in df.columns]

# Create a DataFrame from the list of tuples
columnValue = spark.createDataFrame(unique_counts, ["Column_name", "Unique_values"])
columnValue.show()
# Out:
# +----------------+-------------+
# |     Column_name|Unique_values|
# +----------------+-------------+
# |  transaction_id|       149116|
# |transaction_date|          181|
# |transaction_time|        25762|
# | transaction_qty|            6|
# |        store_id|            3|
# |  store_location|            3|
# |      product_id|           80|
# |      unit_price|           41|
# |product_category|            9|
# |    product_type|           29|
# |  product_detail|           80|
# +----------------+-------------+

# %%
# Explore the frequency of different categories
df.groupBy("product_category").count().orderBy("count", ascending=False).show()
# Out:
# +------------------+-----+
# |  product_category|count|
# +------------------+-----+
# |            Coffee|58416|
# |               Tea|45449|
# |            Bakery|22796|
# |Drinking Chocolate|11468|
# |          Flavours| 6790|
# |      Coffee beans| 1753|
# |         Loose Tea| 1210|
# |           Branded|  747|
# |Packaged Chocolate|  487|
# +------------------+-----+

# %%
df.groupBy("product_type").count().orderBy("count", ascending=False).show()
# Out:
# +--------------------+-----+
# |        product_type|count|
# +--------------------+-----+
# |     Brewed Chai tea|17183|
# |Gourmet brewed co...|16912|
# |    Barista Espresso|16403|
# |       Hot chocolate|11468|
# |    Brewed Black tea|11350|
# |   Brewed herbal tea|11245|
# |               Scone|10173|
# |Organic brewed co...| 8489|
# |         Drip coffee| 8477|
# |Premium brewed co...| 8135|
# |              Pastry| 6912|
# |            Biscotti| 5711|
# |    Brewed Green tea| 5671|
# |       Regular syrup| 4979|
# |    Sugar free syrup| 1811|
# |          Housewares|  526|
# |            Chai tea|  443|
# |       Organic Beans|  415|
# |       Gourmet Beans|  366|
# |       Premium Beans|  336|
# +--------------------+-----+
# only showing top 20 rows

# %% [markdown]
# # Perform Data Transformation

# %%
# Calculate 'Total Sales'
df = df.withColumn("Total_sales", col("unit_price") * col("transaction_qty"))

df.show()
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|  product_category|        product_type|      product_detail|Total_sales|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+
# |             6|      2023-01-01|2024-08-22 07:22:41|              1|       5|Lower Manhattan|        77|       3.0|            Bakery|               Scone|       Oatmeal Scone|        3.0|
# |            10|      2023-01-01|2024-08-22 07:39:34|              2|       5|Lower Manhattan|        58|       3.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Rg|        7.0|
# |             1|      2023-01-01|2024-08-22 07:06:11|              2|       5|Lower Manhattan|        32|       3.0|            Coffee|Gourmet brewed co...|         Ethiopia Rg|        6.0|
# |             8|      2023-01-01|2024-08-22 07:33:34|              2|       5|Lower Manhattan|        28|       2.0|            Coffee|Gourmet brewed co...|Columbian Medium ...|        4.0|
# |            16|      2023-01-01|2024-08-22 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|               Tea|    Brewed Green tea|Serenity Green Te...|        6.0|
# |             9|      2023-01-01|2024-08-22 07:39:13|              1|       5|Lower Manhattan|        39|      4.25|            Coffee|    Barista Espresso|            Latte Rg|       4.25|
# |            12|      2023-01-01|2024-08-22 07:44:35|              2|       5|Lower Manhattan|        33|       3.5|            Coffee|Gourmet brewed co...|         Ethiopia Lg|        7.0|
# |             3|      2023-01-01|2024-08-22 07:14:04|              2|       5|Lower Manhattan|        59|       4.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Lg|        9.0|
# |             2|      2023-01-01|2024-08-22 07:08:56|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|        6.2|
# |             5|      2023-01-01|2024-08-22 07:22:41|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|        6.2|
# |            21|      2023-01-01|2024-08-22 08:17:27|              2|       8| Hell's Kitchen|        33|       3.5|            Coffee|Gourmet brewed co...|         Ethiopia Lg|        7.0|
# |            18|      2023-01-01|2024-08-22 08:00:18|              1|       8| Hell's Kitchen|        42|       2.5|               Tea|   Brewed herbal tea|      Lemon Grass Rg|        2.5|
# |             4|      2023-01-01|2024-08-22 07:20:24|              1|       5|Lower Manhattan|        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|        2.0|
# |             7|      2023-01-01|2024-08-22 07:25:49|              1|       5|Lower Manhattan|        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|        2.0|
# |            17|      2023-01-01|2024-08-22 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|            Bakery|               Scone|  Jumbo Savory Scone|       3.75|
# |            13|      2023-01-01|2024-08-22 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|               Tea|    Brewed Black tea|        Earl Grey Lg|        3.0|
# |            19|      2023-01-01|2024-08-22 08:00:39|              2|       8| Hell's Kitchen|        59|       4.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Lg|        9.0|
# |            11|      2023-01-01|2024-08-22 07:43:05|              1|       5|Lower Manhattan|        56|      2.55|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|       2.55|
# |            15|      2023-01-01|2024-08-22 07:52:36|              2|       5|Lower Manhattan|        87|       3.0|            Coffee|    Barista Espresso|Ouro Brasileiro shot|        6.0|
# |            14|      2023-01-01|2024-08-22 07:48:19|              1|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|        3.1|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql import functions as F

# Assuming 'transaction_date' is in string format, convert it to DateType
df = df.withColumn("transaction_date", F.to_date(F.col("transaction_date"), "dd/MM/yyyy"))
df = df.withColumn("transaction_time", F.col("transaction_time").cast("timestamp"))
df.show()
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|  product_category|        product_type|      product_detail|Total_sales|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+
# |             6|      2023-01-01|2024-08-22 07:22:41|              1|       5|Lower Manhattan|        77|       3.0|            Bakery|               Scone|       Oatmeal Scone|        3.0|
# |            10|      2023-01-01|2024-08-22 07:39:34|              2|       5|Lower Manhattan|        58|       3.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Rg|        7.0|
# |             1|      2023-01-01|2024-08-22 07:06:11|              2|       5|Lower Manhattan|        32|       3.0|            Coffee|Gourmet brewed co...|         Ethiopia Rg|        6.0|
# |             8|      2023-01-01|2024-08-22 07:33:34|              2|       5|Lower Manhattan|        28|       2.0|            Coffee|Gourmet brewed co...|Columbian Medium ...|        4.0|
# |            16|      2023-01-01|2024-08-22 07:59:58|              2|       5|Lower Manhattan|        47|       3.0|               Tea|    Brewed Green tea|Serenity Green Te...|        6.0|
# |             9|      2023-01-01|2024-08-22 07:39:13|              1|       5|Lower Manhattan|        39|      4.25|            Coffee|    Barista Espresso|            Latte Rg|       4.25|
# |            12|      2023-01-01|2024-08-22 07:44:35|              2|       5|Lower Manhattan|        33|       3.5|            Coffee|Gourmet brewed co...|         Ethiopia Lg|        7.0|
# |             3|      2023-01-01|2024-08-22 07:14:04|              2|       5|Lower Manhattan|        59|       4.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Lg|        9.0|
# |             2|      2023-01-01|2024-08-22 07:08:56|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|        6.2|
# |             5|      2023-01-01|2024-08-22 07:22:41|              2|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|        6.2|
# |            21|      2023-01-01|2024-08-22 08:17:27|              2|       8| Hell's Kitchen|        33|       3.5|            Coffee|Gourmet brewed co...|         Ethiopia Lg|        7.0|
# |            18|      2023-01-01|2024-08-22 08:00:18|              1|       8| Hell's Kitchen|        42|       2.5|               Tea|   Brewed herbal tea|      Lemon Grass Rg|        2.5|
# |             4|      2023-01-01|2024-08-22 07:20:24|              1|       5|Lower Manhattan|        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|        2.0|
# |             7|      2023-01-01|2024-08-22 07:25:49|              1|       5|Lower Manhattan|        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|        2.0|
# |            17|      2023-01-01|2024-08-22 07:59:58|              1|       5|Lower Manhattan|        79|      3.75|            Bakery|               Scone|  Jumbo Savory Scone|       3.75|
# |            13|      2023-01-01|2024-08-22 07:45:51|              1|       5|Lower Manhattan|        51|       3.0|               Tea|    Brewed Black tea|        Earl Grey Lg|        3.0|
# |            19|      2023-01-01|2024-08-22 08:00:39|              2|       8| Hell's Kitchen|        59|       4.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Lg|        9.0|
# |            11|      2023-01-01|2024-08-22 07:43:05|              1|       5|Lower Manhattan|        56|      2.55|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|       2.55|
# |            15|      2023-01-01|2024-08-22 07:52:36|              2|       5|Lower Manhattan|        87|       3.0|            Coffee|    Barista Espresso|Ouro Brasileiro shot|        6.0|
# |            14|      2023-01-01|2024-08-22 07:48:19|              1|       5|Lower Manhattan|        57|       3.1|               Tea|     Brewed Chai tea|Spicy Eye Opener ...|        3.1|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+
# only showing top 20 rows

# %%
df.printSchema()
# Out:
# root
#  |-- transaction_id: integer (nullable = true)
#  |-- transaction_date: date (nullable = true)
#  |-- transaction_time: timestamp (nullable = true)
#  |-- transaction_qty: integer (nullable = true)
#  |-- store_id: integer (nullable = true)
#  |-- store_location: string (nullable = true)
#  |-- product_id: integer (nullable = true)
#  |-- unit_price: double (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- product_type: string (nullable = true)
#  |-- product_detail: string (nullable = true)
#  |-- Total_sales: double (nullable = true)

# %%
# Add a new column 'year' extracted from 'transaction_date'
df = df.withColumn("year", F.year(F.col("transaction_date")))

# Add a new column 'month' extracted from 'transaction_date'
df = df.withColumn("month", F.date_format(F.col("transaction_date"), "MMMM"))

# Add a new column 'day' extracted from 'transaction_date'
df = df.withColumn("day", F.date_format(F.col("transaction_date"), "EEEE"))

df.show()
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+----+-------+---------+
# |transaction_id|transaction_date|   transaction_time|transaction_qty|store_id| store_location|product_id|unit_price|  product_category|        product_type|      product_detail|Total_sales|year|  month|      day|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+----+-------+---------+
# |           153|      2023-01-01|2024-08-22 11:57:17|              2|       3|        Astoria|        37|       3.0|            Coffee|    Barista Espresso|       Espresso shot|        6.0|2023|January|   Sunday|
# |           447|      2023-01-01|2024-08-22 17:37:26|              1|       8| Hell's Kitchen|        42|       2.5|               Tea|   Brewed herbal tea|      Lemon Grass Rg|        2.5|2023|January|   Sunday|
# |           800|      2023-01-02|2024-08-22 13:40:53|              1|       5|Lower Manhattan|        79|      3.75|            Bakery|               Scone|  Jumbo Savory Scone|       3.75|2023|January|   Monday|
# |           888|      2023-01-02|2024-08-22 15:27:43|              1|       3|        Astoria|        58|       3.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Rg|        3.5|2023|January|   Monday|
# |           989|      2023-01-02|2024-08-22 17:02:59|              1|       5|Lower Manhattan|        77|       3.0|            Bakery|               Scone|       Oatmeal Scone|        3.0|2023|January|   Monday|
# |          1233|      2023-01-03|2024-08-22 11:23:56|              1|       8| Hell's Kitchen|        54|       2.5|               Tea|     Brewed Chai tea|Morning Sunrise C...|        2.5|2023|January|  Tuesday|
# |          1876|      2023-01-04|2024-08-22 12:59:15|              1|       3|        Astoria|        39|      4.25|            Coffee|    Barista Espresso|            Latte Rg|       4.25|2023|January|Wednesday|
# |          1908|      2023-01-04|2024-08-22 13:48:50|              2|       3|        Astoria|        53|       3.0|               Tea|     Brewed Chai tea|Traditional Blend...|        6.0|2023|January|Wednesday|
# |          2056|      2023-01-04|2024-08-22 16:58:22|              1|       3|        Astoria|        71|      3.75|            Bakery|              Pastry| Chocolate Croissant|       3.75|2023|January|Wednesday|
# |          2117|      2023-01-04|2024-08-22 18:11:39|              2|       8| Hell's Kitchen|        24|       3.0|            Coffee|         Drip coffee|Our Old Time Dine...|        6.0|2023|January|Wednesday|
# |          2171|      2023-01-04|2024-08-22 19:22:43|              2|       3|        Astoria|        30|       3.0|            Coffee|Gourmet brewed co...|Columbian Medium ...|        6.0|2023|January|Wednesday|
# |          3153|      2023-01-06|2024-08-22 17:19:08|              2|       3|        Astoria|        58|       3.5|Drinking Chocolate|       Hot chocolate|   Dark chocolate Rg|        7.0|2023|January|   Friday|
# |          3209|      2023-01-06|2024-08-22 18:24:52|              2|       5|Lower Manhattan|        37|       3.0|            Coffee|    Barista Espresso|       Espresso shot|        6.0|2023|January|   Friday|
# |          3472|      2023-01-07|2024-08-22 09:37:41|              2|       8| Hell's Kitchen|        61|      4.75|Drinking Chocolate|       Hot chocolate|Sustainably Grown...|        9.5|2023|January| Saturday|
# |          3566|      2023-01-07|2024-08-22 10:38:40|              1|       8| Hell's Kitchen|        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|        2.0|2023|January| Saturday|
# |          3573|      2023-01-07|2024-08-22 10:44:03|              2|       5|Lower Manhattan|        40|      3.75|            Coffee|    Barista Espresso|          Cappuccino|        7.5|2023|January| Saturday|
# |          3969|      2023-01-08|2024-08-22 09:12:22|              1|       5|Lower Manhattan|        36|      3.75|            Coffee|Premium brewed co...|Jamaican Coffee R...|       3.75|2023|January|   Sunday|
# |          4114|      2023-01-08|2024-08-22 10:54:37|              2|       5|Lower Manhattan|        31|       2.2|            Coffee|Gourmet brewed co...|         Ethiopia Sm|        4.4|2023|January|   Sunday|
# |          4216|      2023-01-08|2024-08-22 13:35:32|              2|       5|Lower Manhattan|        49|       3.0|               Tea|    Brewed Black tea|English Breakfast Lg|        6.0|2023|January|   Sunday|
# |          4282|      2023-01-08|2024-08-22 16:01:25|              2|       5|Lower Manhattan|        65|       0.8|          Flavours|    Sugar free syrup|Sugar Free Vanill...|        1.6|2023|January|   Sunday|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+----+-------+---------+
# only showing top 20 rows

# %%
# Get unique values in the 'year' ,'month','day'column
unique_year = df.select("year").distinct().show()
unique_month = df.select("month").distinct().show()
unique_day = df.select("day").distinct().show()
unique_product_category = df.select("product_category").distinct().show()
unique_store_location = df.select("store_location").distinct().show()
# Out:
# +----+
# |year|
# +----+
# |2023|
# +----+
#
# +--------+
# |   month|
# +--------+
# |February|
# | January|
# |   March|
# |   April|
# |     May|
# |    June|
# +--------+
#
# +---------+
# |      day|
# +---------+
# |Wednesday|
# |  Tuesday|
# |   Friday|
# | Thursday|
# | Saturday|
# |   Monday|
# |   Sunday|
# +---------+
#
# +------------------+
# |  product_category|
# +------------------+
# |            Bakery|
# |         Loose Tea|
# |Drinking Chocolate|
# |               Tea|
# |           Branded|
# |            Coffee|
# |      Coffee beans|
# |Packaged Chocolate|
# |          Flavours|
# +------------------+
#
# +---------------+
# | store_location|
# +---------------+
# |Lower Manhattan|
# | Hell's Kitchen|
# |        Astoria|
# +---------------+

# %%
# Add a new column 'hour' extracted from 'transaction_time'
df = df.withColumn("hour", F.hour(F.col("transaction_time")))

# Add a new column 'hour' extracted from 'transaction_time'
df = df.withColumn("minute", F.minute(F.col("transaction_time")))

# Add a new column 'hour' extracted from 'transaction_time'
df = df.withColumn("second", F.second(F.col("transaction_time")))

# Show the updated DataFrame
df.show()
# Out:
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------
        22|       2.0|            Coffee|         Drip coffee|Our Old Time Dine...|        2.0|2023|January| Saturday|  10|    38|    40|
# |          3573|      2023-01-07|2024-08-22 10:44:03|              2|       5|Lower Manhattan|        40|      3.75|            Coffee|    Barista Espresso|          Cappuccino|        7.5|2023|January| Saturday|  10|    44|     3|
# |          3969|      2023-01-08|2024-08-22 09:12:22|              1|       5|Lower Manhattan|        36|      3.75|            Coffee|Premium brewed co...|Jamaican Coffee R...|       3.75|2023|January|   Sunday|   9|    12|    22|
# |          4114|      2023-01-08|2024-08-22 10:54:37|              2|       5|Lower Manhattan|        31|       2.2|            Coffee|Gourmet brewed co...|         Ethiopia Sm|        4.4|2023|January|   Sunday|  10|    54|    37|
# |          4216|      2023-01-08|2024-08-22 13:35:32|              2|       5|Lower Manhattan|        49|       3.0|               Tea|    Brewed Black tea|English Breakfast Lg|        6.0|2023|January|   Sunday|  13|    35|    32|
# |          4282|      2023-01-08|2024-08-22 16:01:25|              2|       5|Lower Manhattan|        65|       0.8|          Flavours|    Sugar free syrup|Sugar Free Vanill...|        1.6|2023|January|   Sunday|  16|     1|    25|
# +--------------+----------------+-------------------+---------------+--------+---------------+----------+----------+------------------+--------------------+--------------------+-----------+----+-------+---------+----+------+------+
# only showing top 20 rows

# %% [markdown]
# # Visualization

# %%
df.createOrReplaceTempView('Coffee_data')

# %%
# %sql
select * from Coffee_data limit 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>transaction_id</th><th>transaction_date</th><th>transaction_time</th><th>transaction_qty</th><th>store_id</th><th>store_location</th><th>product_id</th><th>unit_price</th><th>product_category</th><th>product_type</th><th>product_detail</th><th>Total_sales</th><th>year</th><th>month</th><th>day</th><th>hour</th><th>minute</th><th>second</th></tr></thead><tbody><tr><td>153</td><td>2023-01-01</td><td>2024-08-22T11:57:17.000+0000</td><td>2</td><td>3</td><td>Astoria</td><td>37</td><td>3.0</td><td>Coffee</td><td>Barista Espresso</td><td>Espresso shot</td><td>6.0</td><td>2023</td><td>January</td><td>Sunday</td><td>11</td><td>57</td><td>17</td></tr><tr><td>447</td><td>2023-01-01</td><td>2024-08-22T17:37:26.000+0000</td><td>1</td><td>8</td><td>Hell's Kitchen</td><td>42</td><td>2.5</td><td>Tea</td><td>Brewed herbal tea</td><td>Lemon Grass Rg</td><td>2.5</td><td>2023</td><td>January</td><td>Sunday</td><td>17</td><td>37</td><td>26</td></tr><tr><td>800</td><td>2023-01-02</td><td>2024-08-22T13:40:53.000+0000</td><td>1</td><td>5</td><td>Lower Manhattan</td><td>79</td><td>3.75</td><td>Bakery</td><td>Scone</td><td>Jumbo Savory Scone</td><td>3.75</td><td>2023</td><td>January</td><td>Monday</td><td>13</td><td>40</td><td>53</td></tr><tr><td>888</td><td>2023-01-02</td><td>2024-08-22T15:27:43.000+0000</td><td>1</td><td>3</td><td>Astoria</td><td>58</td><td>3.5</td><td>Drinking Chocolate</td><td>Hot chocolate</td><td>Dark chocolate Rg</td><td>3.5</td><td>2023</td><td>January</td><td>Monday</td><td>15</td><td>27</td><td>43</td></tr><tr><td>989</td><td>2023-01-02</td><td>2024-08-22T17:02:59.000+0000</td><td>1</td><td>5</td><td>Lower Manhattan</td><td>77</td><td>3.0</td><td>Bakery</td><td>Scone</td><td>Oatmeal Scone</td><td>3.0</td><td>2023</td><td>January</td><td>Monday</td><td>17</td><td>2</td><td>59</td></tr></tbody></table></div>

# %%
# %sql 
-- Total sales by product category
select product_category,sum(Total_sales) from Coffee_data group by product_category
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_category</th><th>sum(Total_sales)</th></tr></thead><tbody><tr><td>Bakery</td><td>82315.63999999994</td></tr><tr><td>Loose Tea</td><td>11213.600000000022</td></tr><tr><td>Drinking Chocolate</td><td>72416.0</td></tr><tr><td>Tea</td><td>196405.94999999908</td></tr><tr><td>Branded</td><td>13607.0</td></tr><tr><td>Coffee</td><td>269952.45000000333</td></tr><tr><td>Coffee beans</td><td>40085.24999999999</td></tr><tr><td>Packaged Chocolate</td><td>4407.640000000001</td></tr><tr><td>Flavours</td><td>8408.79999999998</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
-- Top 5 Total_sales by product detail
select product_type,sum(Total_sales) as Total_sales from Coffee_data group by product_type order by Total_sales desc limit 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_type</th><th>Total_sales</th></tr></thead><tbody><tr><td>Barista Espresso</td><td>91406.20000000014</td></tr><tr><td>Brewed Chai tea</td><td>77081.9500000005</td></tr><tr><td>Hot chocolate</td><td>72416.0</td></tr><tr><td>Gourmet brewed coffee</td><td>70034.59999999967</td></tr><tr><td>Brewed Black tea</td><td>47932.0</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
-- Lowest 5 Total_sales by product detail
select product_type,sum(Total_sales) as Total_sales from Coffee_data group by product_type order by Total_sales limit 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_type</th><th>Total_sales</th></tr></thead><tbody><tr><td>Green beans</td><td>1340.0</td></tr><tr><td>Green tea</td><td>1470.75</td></tr><tr><td>Organic Chocolate</td><td>1679.5999999999992</td></tr><tr><td>Sugar free syrup</td><td>2324.0000000000036</td></tr><tr><td>Black tea</td><td>2711.849999999998</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
-- product type vs Total Quantity sold
-- Top 10
select product_type,store_location,sum(transaction_qty) as `Total_qty` from Coffee_data group by product_type,store_location order by Total_qty desc limit 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_type</th><th>store_location</th><th>Total_qty</th></tr></thead><tbody><tr><td>Brewed Chai tea</td><td>Astoria</td><td>9306</td></tr><tr><td>Barista Espresso</td><td>Hell's Kitchen</td><td>9064</td></tr><tr><td>Gourmet brewed coffee</td><td>Astoria</td><td>8938</td></tr><tr><td>Brewed Chai tea</td><td>Hell's Kitchen</td><td>8755</td></tr><tr><td>Gourmet brewed coffee</td><td>Lower Manhattan</td><td>8563</td></tr><tr><td>Barista Espresso</td><td>Lower Manhattan</td><td>8534</td></tr><tr><td>Gourmet brewed coffee</td><td>Hell's Kitchen</td><td>8472</td></tr><tr><td>Brewed Chai tea</td><td>Lower Manhattan</td><td>8189</td></tr><tr><td>Barista Espresso</td><td>Astoria</td><td>7345</td></tr><tr><td>Hot chocolate</td><td>Astoria</td><td>6351</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
-- Total sales vs month
select sum(Total_sales),month from Coffee_data group by month ;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sum(Total_sales)</th><th>month</th></tr></thead><tbody><tr><td>76145.19000000009</td><td>February</td></tr><tr><td>81677.74000000014</td><td>January</td></tr><tr><td>98834.68000000018</td><td>March</td></tr><tr><td>156727.7600000003</td><td>May</td></tr><tr><td>118941.08000000031</td><td>April</td></tr><tr><td>166485.8800000002</td><td>June</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
# %sql
-- transation date vs total sales
select sum(Total_sales) as `Total_sales`,transaction_date from Coffee_data group by transaction_date
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>